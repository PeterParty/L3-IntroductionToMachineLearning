# %% [markdown]
# # L3-IntroductionToMachineLearning

# %% [markdown]
# ## Librariile folosite
# - jupyter notebook
#
# ## Provocari și modicicari de cod
#
#  - [ ] În crearea unui nou python virtual environment (cu vresunea de 3.12.10) primul venv a fost creat cu lipsuri iar al doilea a fost creat bine - Cauze :definirea gresita a `enviromnet varables`
#
# ## Features
#
# ## Mod de lucru
